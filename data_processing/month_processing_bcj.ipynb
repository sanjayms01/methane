# %%
import numpy as np
import pandas as pd
import time 
from datetime import datetime
import random
from random import randrange
from datetime import timedelta
import os
import glob
import subprocess
import re
import traceback

# %%
#### CONFIG ####
pipeline_start = True
bucket = 'methane-capstone'
subfolder = 'month-raw-data'
s3_path = bucket+'/data/testsite2/'+subfolder
s3_batch_raw_path = bucket+'/data/testsite2/batch-raw-data'

years = ['2018', '2019', '2020','2021']
columns = ['time_utc', 
           'lat', 'lon', 
           'rn_lat_1','rn_lon_1',
           'rn_lat_2','rn_lon_2',
           'rn_lat_5','rn_lon_5',
           'rn_lat','rn_lon',
           'qa_val', 
           'methane_mixing_ratio',
           'methane_mixing_ratio_precision',
           'methane_mixing_ratio_bias_corrected']

if pipeline_start:
    
    debut = time.time()
    print("######### MONTHLY PIPELINE STARTED #########")
    
    for year in years:

        # All files ending with .parquet.gzip
        file_names = subprocess.check_output(['aws','s3','ls', f's3://{s3_batch_raw_path}/{year}/'])
        vals = [entry.decode('utf-8') for entry in file_names.split()]
        zip_file_names = [x for x in vals if '.gzip' in x]

        print(f"year: {year}, num_files: {len(zip_file_names)}")

        #Load 1 year worth of data
        start_load = time.time()
        df_year = pd.DataFrame(columns=columns, dtype='object')
        for file_name in zip_file_names:
            df_cur_batch = pd.read_parquet(f's3://{s3_batch_raw_path}/{year}/{file_name}')
            print(f"\t file_name: {file_name}, shape: {df_cur_batch.shape}")
            df_year = pd.concat([df_year, df_cur_batch], ignore_index=True)

        #Add `year-month` column
        df_year['time_utc'] = pd.to_datetime(df_year['time_utc'], infer_datetime_format=True)
        df_year.insert(1, 'year_month', df_year['time_utc'].dt.to_period('M').astype(str))
        end_load = time.time()
        
        print(f"\t load_time: {end_load - start_load}, shape: {df_year.shape}, month_coverage: {df_year['year_month'].nunique()}")
        print()
        
        # For every `year-month`
        for period in sorted(df_year['year_month'].unique()):
            df_year_month = df_year[df_year['year_month'] == period]
            df_year_month = df_year_month[df_year_month['qa_val'] >= 0.5]
            df_year_month = df_year_month.sort_values(by=['time_utc'])
            new_file_name = f'{str(period)}' + '-meth.parquet.gzip'
            s3_file_path = 's3://{}/{}'.format(s3_path+f'/{year}', new_file_name)
            print(f"\t\t writing to S3: {s3_file_path}")
            df_year_month.to_parquet(s3_file_path, compression='gzip', coerce_timestamps="us")
        print()
    fin = time.time()
    print(f"MONTHLY PIPELINE DONE, time_taken:{fin-debut}")
else:
    print("MONTHLY PIPELINE CLOSED")
# Out:
# ######### MONTHLY PIPELINE STARTED #########
# year: 2018, num_files: 5
# 	 file_name: 20181201_20181206_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20181207_20181213_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20181214_20181219_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20181220_20181225_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20181226_20181231_meth.parquet.gzip, shape: (0, 15)
# 	 load_time: 0.33514881134033203, shape: (0, 16), month_coverage: 0
#
#
# year: 2019, num_files: 83
# 	 file_name: 20190101_20190106_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20190107_20190112_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20190113_20190119_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20190119_20190124_meth.parquet.gzip, shape: (18, 15)
# 	 file_name: 20190125_20190130_meth.parquet.gzip, shape: (708, 15)
# 	 file_name: 20190131_20190205_meth.parquet.gzip, shape: (79, 15)
# 	 file_name: 20190206_20190211_meth.parquet.gzip, shape: (129, 15)
# 	 file_name: 20190212_20190217_meth.parquet.gzip, shape: (10, 15)
# 	 file_name: 20190218_20190223_meth.parquet.gzip, shape: (525, 15)
# 	 file_name: 20190224_20190301_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20190302_20190307_meth.parquet.gzip, shape: (1010, 15)
# 	 file_name: 20190308_20190313_meth.parquet.gzip, shape: (681, 15)
# 	 file_name: 20190313_20190319_meth.parquet.gzip, shape: (586, 15)
# 	 file_name: 20190319_20190325_meth.parquet.gzip, shape: (166, 15)
# 	 file_name: 20190325_20190331_meth.parquet.gzip, shape: (112, 15)
# 	 file_name: 20190331_20190406_meth.parquet.gzip, shape: (200, 15)
# 	 file_name: 20190406_20190412_meth.parquet.gzip, shape: (27, 15)
# 	 file_name: 20190412_20190417_meth.parquet.gzip, shape: (493, 15)
# 	 file_name: 20190418_20190421_meth.parquet.gzip, shape: (626, 15)
# 	 file_name: 20190422_20190425_meth.parquet.gzip, shape: (161, 15)
# 	 file_name: 20190425_20190429_meth.parquet.gzip, shape: (451, 15)
# 	 file_name: 20190429_20190503_meth.parquet.gzip, shape: (342, 15)
# 	 file_name: 20190503_20190506_meth.parquet.gzip, shape: (313, 15)
# 	 file_name: 20190506_20190509_meth.parquet.gzip, shape: (158, 15)
# 	 file_name: 20190509_20190512_meth.parquet.gzip, shape: (683, 15)
# 	 file_name: 20190512_20190515_meth.parquet.gzip, shape: (393, 15)
# 	 file_name: 20190515_20190518_meth.parquet.gzip, shape: (1, 15)
# 	 file_name: 20190518_20190521_meth.parquet.gzip, shape: (69, 15)
# 	 file_name: 20190521_20190524_meth.parquet.gzip, shape: (12, 15)
# 	 file_name: 20190525_20190527_meth.parquet.gzip, shape: (125, 15)
# 	 file_name: 20190527_20190530_meth.parquet.gzip, shape: (494, 15)
# 	 file_name: 20190531_20190602_meth.parquet.gzip, shape: (511, 15)
# 	 file_name: 20190602_20190603_meth.parquet.gzip, shape: (20, 15)
# 	 file_name: 20190604_20190606_meth.parquet.gzip, shape: (400, 15)
# 	 file_name: 20190606_20190610_meth.parquet.gzip, shape: (1627, 15)
# 	 file_name: 20190610_20190613_meth.parquet.gzip, shape: (148, 15)
# 	 file_name: 20190613_20190616_meth.parquet.gzip, shape: (27, 15)
# 	 file_name: 20190616_20190619_meth.parquet.gzip, shape: (355, 15)
# 	 file_name: 20190619_20190622_meth.parquet.gzip, shape: (65, 15)
# 	 file_name: 20190622_20190625_meth.parquet.gzip, shape: (165, 15)
# 	 file_name: 20190625_20190628_meth.parquet.gzip, shape: (4, 15)
# 	 file_name: 20190628_20190630_meth.parquet.gzip, shape: (18, 15)
# 	 file_name: 20190701_20190703_meth.parquet.gzip, shape: (112, 15)
# 	 file_name: 20190703_20190707_meth.parquet.gzip, shape: (24, 15)
# 	 file_name: 20190707_20190709_meth.parquet.gzip, shape: (17, 15)
# 	 file_name: 20190710_20190713_meth.parquet.gzip, shape: (16, 15)
# 	 file_name: 20190713_20190717_meth.parquet.gzip, shape: (117, 15)
# 	 file_name: 20190717_20190719_meth.parquet.gzip, shape: (408, 15)
# 	 file_name: 20190720_20190723_meth.parquet.gzip, shape: (64, 15)
# 	 file_name: 20190723_20190725_meth.parquet.gzip, shape: (13, 15)
# 	 file_name: 20190726_20190729_meth.parquet.gzip, shape: (26, 15)
# 	 file_name: 20190729_20190731_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20190801_20190804_meth.parquet.gzip, shape: (7, 15)
# 	 file_name: 20190804_20190807_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20190807_20190810_meth.parquet.gzip, shape: (4, 15)
# 	 file_name: 20190810_20190814_meth.parquet.gzip, shape: (43, 15)
# 	 file_name: 20190814_20190818_meth.parquet.gzip, shape: (526, 15)
# 	 file_name: 20190818_20190822_meth.parquet.gzip, shape: (115, 15)
# 	 file_name: 20190823_20190827_meth.parquet.gzip, shape: (260, 15)
# 	 file_name: 20190827_20190901_meth.parquet.gzip, shape: (828, 15)
# 	 file_name: 20190902_20190907_meth.parquet.gzip, shape: (106, 15)
# 	 file_name: 20190908_20190913_meth.parquet.gzip, shape: (909, 15)
# 	 file_name: 20190914_20190919_meth.parquet.gzip, shape: (96, 15)
# 	 file_name: 20190920_20190925_meth.parquet.gzip, shape: (3, 15)
# 	 file_name: 20190926_20191001_meth.parquet.gzip, shape: (33, 15)
# 	 file_name: 20191002_20191007_meth.parquet.gzip, shape: (82, 15)
# 	 file_name: 20191007_20191013_meth.parquet.gzip, shape: (10, 15)
# 	 file_name: 20191013_20191019_meth.parquet.gzip, shape: (1, 15)
# 	 file_name: 20191019_20191025_meth.parquet.gzip, shape: (166, 15)
# 	 file_name: 20191025_20191031_meth.parquet.gzip, shape: (81, 15)
# 	 file_name: 20191031_20191106_meth.parquet.gzip, shape: (35, 15)
# 	 file_name: 20191106_20191112_meth.parquet.gzip, shape: (2, 15)
# 	 file_name: 20191112_20191118_meth.parquet.gzip, shape: (33, 15)
# 	 file_name: 20191118_20191124_meth.parquet.gzip, shape: (29, 15)
# 	 file_name: 20191124_20191129_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20191130_20191205_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20191201_20191206_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20191206_20191211_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20191207_20191212_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20191212_20191217_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20191218_20191223_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20191224_20191229_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20191230_20191231_meth.parquet.gzip, shape: (0, 15)
# 	 load_time: 5.257280111312866, shape: (16078, 16), month_coverage: 11
#
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-01-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-02-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-03-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-04-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-05-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-06-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-07-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-08-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-09-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-10-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-11-meth.parquet.gzip
#
# year: 2020, num_files: 81
# 	 file_name: 20200101_20200107_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200107_20200113_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200113_20200119_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200119_20200125_meth.parquet.gzip, shape: (66, 15)
# 	 file_name: 20200126_20200131_meth.parquet.gzip, shape: (381, 15)
# 	 file_name: 20200201_20200206_meth.parquet.gzip, shape: (199, 15)
# 	 file_name: 20200207_20200212_meth.parquet.gzip, shape: (897, 15)
# 	 file_name: 20200212_20200218_meth.parquet.gzip, shape: (259, 15)
# 	 file_name: 20200218_20200224_meth.parquet.gzip, shape: (658, 15)
# 	 file_name: 20200224_20200301_meth.parquet.gzip, shape: (138, 15)
# 	 file_name: 20200301_20200307_meth.parquet.gzip, shape: (627, 15)
# 	 file_name: 20200307_20200313_meth.parquet.gzip, shape: (4, 15)
# 	 file_name: 20200313_20200319_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200319_20200325_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200325_20200331_meth.parquet.gzip, shape: (402, 15)
# 	 file_name: 20200331_20200405_meth.parquet.gzip, shape: (644, 15)
# 	 file_name: 20200406_20200411_meth.parquet.gzip, shape: (441, 15)
# 	 file_name: 20200412_20200416_meth.parquet.gzip, shape: (290, 15)
# 	 file_name: 20200417_20200421_meth.parquet.gzip, shape: (11, 15)
# 	 file_name: 20200421_20200425_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200425_20200428_meth.parquet.gzip, shape: (14, 15)
# 	 file_name: 20200428_20200502_meth.parquet.gzip, shape: (636, 15)
# 	 file_name: 20200502_20200506_meth.parquet.gzip, shape: (1417, 15)
# 	 file_name: 20200506_20200509_meth.parquet.gzip, shape: (1223, 15)
# 	 file_name: 20200509_20200512_meth.parquet.gzip, shape: (297, 15)
# 	 file_name: 20200512_20200515_meth.parquet.gzip, shape: (563, 15)
# 	 file_name: 20200515_20200518_meth.parquet.gzip, shape: (10, 15)
# 	 file_name: 20200518_20200521_meth.parquet.gzip, shape: (20, 15)
# 	 file_name: 20200521_20200524_meth.parquet.gzip, shape: (159, 15)
# 	 file_name: 20200525_20200528_meth.parquet.gzip, shape: (491, 15)
# 	 file_name: 20200528_20200530_meth.parquet.gzip, shape: (1041, 15)
# 	 file_name: 20200531_20200602_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200603_20200605_meth.parquet.gzip, shape: (116, 15)
# 	 file_name: 20200606_20200608_meth.parquet.gzip, shape: (6, 15)
# 	 file_name: 20200608_20200612_meth.parquet.gzip, shape: (1073, 15)
# 	 file_name: 20200612_20200615_meth.parquet.gzip, shape: (809, 15)
# 	 file_name: 20200615_20200618_meth.parquet.gzip, shape: (978, 15)
# 	 file_name: 20200618_20200621_meth.parquet.gzip, shape: (691, 15)
# 	 file_name: 20200621_20200624_meth.parquet.gzip, shape: (182, 15)
# 	 file_name: 20200624_20200627_meth.parquet.gzip, shape: (85, 15)
# 	 file_name: 20200627_20200630_meth.parquet.gzip, shape: (5, 15)
# 	 file_name: 20200630_20200630_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200701_20200704_meth.parquet.gzip, shape: (22, 15)
# 	 file_name: 20200704_20200706_meth.parquet.gzip, shape: (46, 15)
# 	 file_name: 20200707_20200709_meth.parquet.gzip, shape: (1293, 15)
# 	 file_name: 20200710_20200712_meth.parquet.gzip, shape: (1036, 15)
# 	 file_name: 20200713_20200715_meth.parquet.gzip, shape: (971, 15)
# 	 file_name: 20200716_20200719_meth.parquet.gzip, shape: (164, 15)
# 	 file_name: 20200719_20200722_meth.parquet.gzip, shape: (66, 15)
# 	 file_name: 20200722_20200725_meth.parquet.gzip, shape: (22, 15)
# 	 file_name: 20200725_20200728_meth.parquet.gzip, shape: (21, 15)
# 	 file_name: 20200728_20200731_meth.parquet.gzip, shape: (61, 15)
# 	 file_name: 20200731_20200803_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200803_20200806_meth.parquet.gzip, shape: (797, 15)
# 	 file_name: 20200807_20200810_meth.parquet.gzip, shape: (59, 15)
# 	 file_name: 20200810_20200813_meth.parquet.gzip, shape: (207, 15)
# 	 file_name: 20200813_20200817_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20200817_20200821_meth.parquet.gzip, shape: (275, 15)
# 	 file_name: 20200822_20200826_meth.parquet.gzip, shape: (101, 15)
# 	 file_name: 20200826_20200831_meth.parquet.gzip, shape: (999, 15)
# 	 file_name: 20200901_20200906_meth.parquet.gzip, shape: (1564, 15)
# 	 file_name: 20200907_20200912_meth.parquet.gzip, shape: (613, 15)
# 	 file_name: 20200912_20200918_meth.parquet.gzip, shape: (307, 15)
# 	 file_name: 20200918_20200924_meth.parquet.gzip, shape: (796, 15)
# 	 file_name: 20200924_20200930_meth.parquet.gzip, shape: (1450, 15)
# 	 file_name: 20200930_20201006_meth.parquet.gzip, shape: (2372, 15)
# 	 file_name: 20201006_20201012_meth.parquet.gzip, shape: (433, 15)
# 	 file_name: 20201012_20201018_meth.parquet.gzip, shape: (459, 15)
# 	 file_name: 20201018_20201024_meth.parquet.gzip, shape: (128, 15)
# 	 file_name: 20201024_20201030_meth.parquet.gzip, shape: (1249, 15)
# 	 file_name: 20201030_20201105_meth.parquet.gzip, shape: (236, 15)
# 	 file_name: 20201105_20201110_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20201111_20201116_meth.parquet.gzip, shape: (114, 15)
# 	 file_name: 20201117_20201122_meth.parquet.gzip, shape: (127, 15)
# 	 file_name: 20201123_20201128_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20201129_20201205_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20201205_20201211_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20201211_20201217_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20201217_20201223_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20201223_20201228_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20201229_20201231_meth.parquet.gzip, shape: (0, 15)
# 	 load_time: 5.087785720825195, shape: (30821, 16), month_coverage: 11
#
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-01-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-02-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-03-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-04-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-05-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-06-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-07-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-08-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-09-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-10-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-11-meth.parquet.gzip
#
# year: 2021, num_files: 64
# 	 file_name: 20210101_20210106_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20210107_20210113_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20210113_20210118_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20210119_20210124_meth.parquet.gzip, shape: (0, 15)
# 	 file_name: 20210125_20210130_meth.parquet.gzip, shape: (6, 15)
# 	 file_name: 20210131_20210205_meth.parquet.gzip, shape: (684, 15)
# 	 file_name: 20210206_20210211_meth.parquet.gzip, shape: (1546, 15)
# 	 file_name: 20210212_20210217_meth.parquet.gzip, shape: (1327, 15)
# 	 file_name: 20210218_20210223_meth.parquet.gzip, shape: (2725, 15)
# 	 file_name: 20210224_20210301_meth.parquet.gzip, shape: (2127, 15)
# 	 file_name: 20210302_20210307_meth.parquet.gzip, shape: (1048, 15)
# 	 file_name: 20210307_20210313_meth.parquet.gzip, shape: (1750, 15)
# 	 file_name: 20210313_20210319_meth.parquet.gzip, shape: (27, 15)
# 	 file_name: 20210319_20210325_meth.parquet.gzip, shape: (1650, 15)
# 	 file_name: 20210325_20210331_meth.parquet.gzip, shape: (3237, 15)
# 	 file_name: 20210331_20210406_meth.parquet.gzip, shape: (309, 15)
# 	 file_name: 20210406_20210412_meth.parquet.gzip, shape: (253, 15)
# 	 file_name: 20210412_20210416_meth.parquet.gzip, shape: (1223, 15)
# 	 file_name: 20210417_20210421_meth.parquet.gzip, shape: (2551, 15)
# 	 file_name: 20210421_20210424_meth.parquet.gzip, shape: (291, 15)
# 	 file_name: 20210425_20210429_meth.parquet.gzip, shape: (9, 15)
# 	 file_name: 20210429_20210502_meth.parquet.gzip, shape: (46, 15)
# 	 file_name: 20210502_20210505_meth.parquet.gzip, shape: (2, 15)
# 	 file_name: 20210505_20210508_meth.parquet.gzip, shape: (376, 15)
# 	 file_name: 20210509_20210512_meth.parquet.gzip, shape: (577, 15)
# 	 file_name: 20210512_20210515_meth.parquet.gzip, shape: (495, 15)
# 	 file_name: 20210515_20210518_meth.parquet.gzip, shape: (853, 15)
# 	 file_name: 20210518_20210521_meth.parquet.gzip, shape: (1101, 15)
# 	 file_name: 20210521_20210524_meth.parquet.gzip, shape: (101, 15)
# 	 file_name: 20210524_20210527_meth.parquet.gzip, shape: (497, 15)
# 	 file_name: 20210528_20210531_meth.parquet.gzip, shape: (962, 15)
# 	 file_name: 20210531_20210603_meth.parquet.gzip, shape: (350, 15)
# 	 file_name: 20210603_20210606_meth.parquet.gzip, shape: (1579, 15)
# 	 file_name: 20210606_20210609_meth.parquet.gzip, shape: (1026, 15)
# 	 file_name: 20210609_20210611_meth.parquet.gzip, shape: (203, 15)
# 	 file_name: 20210612_20210615_meth.parquet.gzip, shape: (56, 15)
# 	 file_name: 20210616_20210618_meth.parquet.gzip, shape: (1049, 15)
# 	 file_name: 20210619_20210621_meth.parquet.gzip, shape: (839, 15)
# 	 file_name: 20210622_20210624_meth.parquet.gzip, shape: (222, 15)
# 	 file_name: 20210625_20210627_meth.parquet.gzip, shape: (1248, 15)
# 	 file_name: 20210627_20210630_meth.parquet.gzip, shape: (158, 15)
# 	 file_name: 20210701_20210704_meth.parquet.gzip, shape: (82, 15)
# 	 file_name: 20210704_20210707_meth.parquet.gzip, shape: (1521, 15)
# 	 file_name: 20210707_20210710_meth.parquet.gzip, shape: (544, 15)
# 	 file_name: 20210710_20210713_meth.parquet.gzip, shape: (1180, 15)
# 	 file_name: 20210713_20210716_meth.parquet.gzip, shape: (1513, 15)
# 	 file_name: 20210716_20210719_meth.parquet.gzip, shape: (929, 15)
# 	 file_name: 20210719_20210723_meth.parquet.gzip, shape: (86, 15)
# 	 file_name: 20210723_20210726_meth.parquet.gzip, shape: (122, 15)
# 	 file_name: 20210726_20210729_meth.parquet.gzip, shape: (487, 15)
# 	 file_name: 20210729_20210801_meth.parquet.gzip, shape: (147, 15)
# 	 file_name: 20210801_20210805_meth.parquet.gzip, shape: (866, 15)
# 	 file_name: 20210805_20210808_meth.parquet.gzip, shape: (855, 15)
# 	 file_name: 20210809_20210812_meth.parquet.gzip, shape: (1382, 15)
# 	 file_name: 20210812_20210815_meth.parquet.gzip, shape: (1083, 15)
# 	 file_name: 20210816_20210820_meth.parquet.gzip, shape: (908, 15)
# 	 file_name: 20210820_20210824_meth.parquet.gzip, shape: (795, 15)
# 	 file_name: 20210824_20210829_meth.parquet.gzip, shape: (1249, 15)
# 	 file_name: 20210829_20210903_meth.parquet.gzip, shape: (1391, 15)
# 	 file_name: 20210904_20210909_meth.parquet.gzip, shape: (39, 15)
# 	 file_name: 20210910_20210915_meth.parquet.gzip, shape: (194, 15)
# 	 file_name: 20210915_20210921_meth.parquet.gzip, shape: (249, 15)
# 	 file_name: 20210921_20210927_meth.parquet.gzip, shape: (106, 15)
# 	 file_name: 20210927_20210930_meth.parquet.gzip, shape: (186, 15)
# 	 load_time: 4.837446451187134, shape: (48417, 16), month_coverage: 9
#
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-01-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-02-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-03-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-04-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-05-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-06-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-07-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-08-meth.parquet.gzip
# 		 writing to S3: s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-09-meth.parquet.gzip
#
# MONTHLY PIPELINE DONE, time_taken:19.370832204818726

# %% [markdown]
# ### Another pass at combining the data to validate the size

# %%
data_key_list_2018 = [ ]#'2018-11-meth.parquet.gzip',  '2018-12-meth.parquet.gzip']

data_key_list_2019 = [ '2019-01-meth.parquet.gzip',  '2019-02-meth.parquet.gzip', '2019-03-meth.parquet.gzip', '2019-04-meth.parquet.gzip', '2019-05-meth.parquet.gzip',
 '2019-06-meth.parquet.gzip', '2019-07-meth.parquet.gzip', '2019-08-meth.parquet.gzip', '2019-09-meth.parquet.gzip', '2019-10-meth.parquet.gzip', '2019-11-meth.parquet.gzip',]#
# '2019-12-meth.parquet.gzip']

data_key_list_2020 = [ '2020-01-meth.parquet.gzip', '2020-02-meth.parquet.gzip', '2020-03-meth.parquet.gzip', '2020-04-meth.parquet.gzip', '2020-05-meth.parquet.gzip',
 '2020-06-meth.parquet.gzip', '2020-07-meth.parquet.gzip', '2020-08-meth.parquet.gzip', '2020-09-meth.parquet.gzip', '2020-10-meth.parquet.gzip', '2020-11-meth.parquet.gzip',]#
# '2020-12-meth.parquet.gzip']

data_key_list_2021 = [ '2021-01-meth.parquet.gzip', '2021-02-meth.parquet.gzip', '2021-03-meth.parquet.gzip', '2021-04-meth.parquet.gzip', '2021-05-meth.parquet.gzip',
 '2021-06-meth.parquet.gzip', '2021-07-meth.parquet.gzip', '2021-08-meth.parquet.gzip', '2021-09-meth.parquet.gzip']


bucket = 'methane-capstone'
subfolder = 'month-raw-data'

def read_sentinel5p(year, filename):
    s3_path = bucket+'/data/testsite2/'+subfolder + '/' + year
    data_location = 's3://{}/{}'.format(s3_path, filename)
    return data_location

print("Check that we have all the months we want")
print(len(data_key_list_2018))
print(len(data_key_list_2019))
print(len(data_key_list_2020))
print(len(data_key_list_2021))
# Out:
# Check that we have all the months we want
# 0
# 11
# 11
# 9

# %%
columns = ['time_utc', 
           'lat', 'lon', 
           'rn_lat_1','rn_lon_1',
           'rn_lat_2','rn_lon_2',
           'rn_lat_5','rn_lon_5',
           'rn_lat','rn_lon',
           'qa_val', 
           'methane_mixing_ratio',
           'methane_mixing_ratio_precision',
           'methane_mixing_ratio_bias_corrected']

df_all = pd.DataFrame(columns=columns, dtype='object')

for year_list_ind, year in enumerate(['2018','2019','2020','2021'], 0):
    
    month_list = []
    if year_list_ind == 0:
        month_list = data_key_list_2018
    elif year_list_ind == 1:
        month_list = data_key_list_2019
    elif year_list_ind == 2:
        month_list = data_key_list_2020
    elif year_list_ind == 3:
        month_list = data_key_list_2021
    else:
        print("WE GOT ISSUES")

    df_cur_year = pd.DataFrame(columns=columns, dtype='object')
    for filename in month_list:
        print(read_sentinel5p(year, filename))
        try:
            df_cur_month = pd.read_parquet(read_sentinel5p(year, filename))
            df_cur_year = pd.concat([df_cur_year, df_cur_month], ignore_index=True)    
            print(f"month: {filename}, shape: {df_cur_month.shape}")
        except Exception:
            #traceback.print_exc()
            print("\tPROBLEM FILE:",filename)

    print(f"Year: {year}, shape: {df_cur_year.shape}")
    df_all = pd.concat([df_all, df_cur_year], ignore_index=True)
    

print(f"Total shape: {df_all.shape}")
# Out:
# Year: 2018, shape: (0, 15)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-01-meth.parquet.gzip
# month: 2019-01-meth.parquet.gzip, shape: (0, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-02-meth.parquet.gzip
# month: 2019-02-meth.parquet.gzip, shape: (201, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-03-meth.parquet.gzip
# month: 2019-03-meth.parquet.gzip, shape: (665, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-04-meth.parquet.gzip
# month: 2019-04-meth.parquet.gzip, shape: (434, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-05-meth.parquet.gzip
# month: 2019-05-meth.parquet.gzip, shape: (803, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-06-meth.parquet.gzip
# month: 2019-06-meth.parquet.gzip, shape: (589, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-07-meth.parquet.gzip
# month: 2019-07-meth.parquet.gzip, shape: (111, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-08-meth.parquet.gzip
# month: 2019-08-meth.parquet.gzip, shape: (269, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-09-meth.parquet.gzip
# month: 2019-09-meth.parquet.gzip, shape: (284, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-10-meth.parquet.gzip
# month: 2019-10-meth.parquet.gzip, shape: (52, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2019/2019-11-meth.parquet.gzip
# month: 2019-11-meth.parquet.gzip, shape: (0, 16)
# Year: 2019, shape: (3408, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-01-meth.parquet.gzip
# month: 2020-01-meth.parquet.gzip, shape: (0, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-02-meth.parquet.gzip
# month: 2020-02-meth.parquet.gzip, shape: (161, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-03-meth.parquet.gzip
# month: 2020-03-meth.parquet.gzip, shape: (32, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-04-meth.parquet.gzip
# month: 2020-04-meth.parquet.gzip, shape: (552, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-05-meth.parquet.gzip
# month: 2020-05-meth.parquet.gzip, shape: (1802, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-06-meth.parquet.gzip
# month: 2020-06-meth.parquet.gzip, shape: (1323, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-07-meth.parquet.gzip
# month: 2020-07-meth.parquet.gzip, shape: (868, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-08-meth.parquet.gzip
# month: 2020-08-meth.parquet.gzip, shape: (568, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-09-meth.parquet.gzip
# month: 2020-09-meth.parquet.gzip, shape: (2296, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-10-meth.parquet.gzip
# month: 2020-10-meth.parquet.gzip, shape: (1956, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2020/2020-11-meth.parquet.gzip
# month: 2020-11-meth.parquet.gzip, shape: (0, 16)
# Year: 2020, shape: (9558, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-01-meth.parquet.gzip
# month: 2021-01-meth.parquet.gzip, shape: (0, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-02-meth.parquet.gzip
# month: 2021-02-meth.parquet.gzip, shape: (2556, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-03-meth.parquet.gzip
# month: 2021-03-meth.parquet.gzip, shape: (3225, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-04-meth.parquet.gzip
# month: 2021-04-meth.parquet.gzip, shape: (2221, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-05-meth.parquet.gzip
# month: 2021-05-meth.parquet.gzip, shape: (2116, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-06-meth.parquet.gzip
# month: 2021-06-meth.parquet.gzip, shape: (3248, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-07-meth.parquet.gzip
# month: 2021-07-meth.parquet.gzip, shape: (2266, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-08-meth.parquet.gzip
# month: 2021-08-meth.parquet.gzip, shape: (4692, 16)
# s3://methane-capstone/data/testsite2/month-raw-data/2021/2021-09-meth.parquet.gzip
# month: 2021-09-meth.parquet.gzip, shape: (159, 16)
# Year: 2021, shape: (20483, 16)
# Total shape: (33449, 16)

# %%
gzip_write_path = 's3://methane-capstone/data/testsite2/combined-raw-data/combined-raw-2.parquet.gzip'
parquet_write_path = 's3://methane-capstone/data/testsite2/combined-raw-data/combined-raw-2.parquet'

# %%
df_all.to_parquet(parquet_write_path, coerce_timestamps="us")

# %%
df_all.to_parquet(gzip_write_path, compression='gzip', coerce_timestamps="us")

# %%
#Cross checking John's write
df_check = pd.read_parquet('s3://methane-capstone/data/testsite2/combined-raw-data/combined-raw-2.parquet')
print(df_check.shape)
# Out:
# (33449, 16)

# %% [markdown]
# ### Checks out perfect!

# %%
# !pwd

# %%
# !jupytext --to py month_processing.ipynb
